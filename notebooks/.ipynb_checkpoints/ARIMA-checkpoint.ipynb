# %% [markdown]
# # ARIMA FOR ANOMALY DETECTION

# %% [markdown]
# ## Importar os Modulos

# %%
import pandas as pd
from janitor import clean_names
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error
import sys
sys.path.append("C:/Users/joaoc/Documents/MT/pagamento_servidores/src")
import process_servants as ps

# %% [markdown]
# ## Função para pre-processamento dos dados
# Utiliza-se funções importadas do arquivo process_servants.py, no qual foram pré-definidas algumas funções para o pré-processamento dos dados

# %%
def process_registration_data(file_path, reference_date_str, cut_date):
    """Process registration data from Excel file"""
    
    df = (
        pd.read_excel(file_path)
        .pipe(clean_names)
        .pipe(ps.convert_rendim_to_numeric)
        .pipe(ps.process_month_column)
        )    
    # Converter para datetime
    reference_date = pd.to_datetime(reference_date_str)
    
    # Calcular data de corte
    cutoff_date = reference_date - pd.DateOffset(months=cut_date)
    
    # Filtrar linhas
    df = df[(df['mes'] >= cutoff_date) & (df['mes'] <= reference_date)].copy()
    
    #Selecionar apesas as colunas necessárias para o modelo
    df_rendim = df[['cpf_servidor', 'mes', 'rendim']]
    #Se tiver valores com o CPF duplicado para o mesmo mês, somar os valores
    df_rendim = df_rendim.groupby(['cpf_servidor', 'mes'])['rendim'].sum().reset_index()
    #Prencer os meses que estão com NA, como "Zero"
    df_rendim = df_rendim.pivot(index = 'cpf_servidor', columns='mes', values='rendim').reset_index()
    df_rendim = df_rendim.fillna(0)
    #Voltar a Tabela para estrutura Vertical
    df_rendim = df_rendim.melt(id_vars =  'cpf_servidor', var_name='mes', value_name='rendim')
        
    return df_rendim

# %% [markdown]
# ## Função para Leitura dos Dados

# %%
def processed_data(brute_data_file_path, file_name, reference_date_str, cut_date):
    registration_df = process_registration_data(brute_data_file_path, reference_date_str, cut_date)
    
    processed_path  = "C:/Users/joaoc/Documents/MT/pagamento_servidores/data/processed/" + file_name + ".xlsx"
    print("Processed data shapes:")
    print(f"Registration data: {registration_df.shape}")
    
    registration_df.to_excel(processed_path, index=False)
        
    return registration_df

# %% [markdown]
# ## Leitura da Base de Dados
# Formato:
# ![image.png](attachment:b5123392-e78d-4399-9f48-f641de9f6461.png)

# %%
brute_file_path = 'C:/Users/joaoc/Documents/MT/pagamento_servidores/data/raw/servidores_mes.xlsx'

# %% [markdown]
# Data de Referencia

# %%
reference_date_str = '2022-04-01'

# %% [markdown]
# Linha de Corte dos Dados -> Ultimos 12 meses, a partir da data de referencia

# %%
cut_date = 12

# %% [markdown]
# ## Processamento da Base de Dados
# Transformação e Categorização dos campos, alem de salvar o dados processados de acordo com "nome_arquivo_salvar"

# %%
nome_arquivo_salvar = "dados_12_meses_cadastro_e_std"
process_df = processed_data(brute_file_path, nome_arquivo_salvar, reference_date_str, cut_date)
# Out:
# C:\Users\joaoc\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Processed data shapes:
# Registration data: (32864, 3)

# %% [markdown]
# ## Analise de todos os Servidores, nos ultimos 12 meses, contados a partir da data de referencia (reference_date_str)

# %%
    resultados = []
    for id in process_df['cpf_servidor'].unique():
        # Filtrar dados do funcionário
        dados = process_df[process_df['cpf_servidor'] == id].sort_values('mes')
        
        if len(dados) < 12:  # Ignorar funcionários com menos de 12 meses de histórico
            continue
        
        serie = dados.set_index('mes')['rendim']
        train, test = serie[:-3], serie[-3:]
        
        try:
            model = ARIMA(train, order=(1, 1, 1)).fit()
            forecast = model.forecast(steps=3)
            conf_int = model.get_forecast(steps=3).conf_int()
            # Converter para arrays
            test_values = test.values
            lower_values = conf_int.iloc[:, 0].values
            upper_values = conf_int.iloc[:, 1].values
            anomalias = (test < conf_int.iloc[:, 0]) | (test > conf_int.iloc[:, 1])
            meses_anomalos = test.index[anomalias]
            
            for mes in meses_anomalos:
                try:
                    total_previsto = round(forecast.loc[mes], 2)
                    total_real = test.loc[mes]
                    erro_absoluto = abs(total_real - total_previsto)
                    
                    resultados.append({
                        'cpf_servidor': id,
                        'mes': mes.strftime('%Y-%m'),
                        'Total Previsto': total_previsto,
                        'Total Real': total_real,
                        'Erro Absoluto': erro_absoluto
                    })
                except KeyError as e:
                    print(f"Erro: Mês {mes} não encontrado. Detalhes: {e}")
                except Exception as e:
                    print(f"Erro inesperado: {e}")
        except:
            continue
    
    # Criar DataFrame de anomalias
    df_anomalias = pd.DataFrame(resultados)
# Out:
# C:\Users\joaoc\anaconda3\envs\pagamentos_servidores\lib\site-packages\pandas\core\indexes\base.py:7588: FutureWarning: Dtype inference on a pandas object (Series, Index, ExtensionArray) is deprecated. The Index constructor will keep the original dtype in the future. Call `infer_objects` on the result to get the old behavior.
#   return Index(sequences[0], name=names)
# C:\Users\joaoc\anaconda3\envs\pagamentos_servidores\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\joaoc\anaconda3\envs\pagamentos_servidores\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# ...
